# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle, copy
from collections import defaultdict
from Networkmodel import NetworkModel_org, HopField

# %%
class NetworkModel(NetworkModel_org):
    def task_condition(self):
        self.HFregister = dict()
        self.actdict = {1: [2], 2: [3,4], 3: [2], 4: [1]}  
        self.initial = 1
        self.terminal = [4]
        self.stmdict = {1: [1], 2: [2], 3: [3], 4:[4]}
        self.cortex_calc = [1]
        self.stmindex = {1:0, 2:0, 3:0, 4:0}
        self.swblock = 20
        for key,val in self.stmdict.items():
            for s in val:
                tmp = np.zeros(self.nstm)
                tmp[np.sort(np.random.choice(len(tmp), int(len(tmp)/2), replace = False))] = 1  
                self.HFregister[s] = tmp
                
    def check_rwd(self, result, count):
        if not result[-1]["cond"] in self.terminal:
            return 0
        swmode = np.mod(np.floor(count/self.swblock),2)
        tmp1 = sum([result[i]["infcond"] for i in range(len(result))], [])
        tmp2 = [result[i]["cond"] for i in range(len(result))]
        cnt1,cnt2 = len(np.where(np.array(tmp1)==3)[0]),len(np.where(np.array(tmp2)==3)[0])
        if count < self.swblock:
            return int(cnt1 + cnt2 == 0)
        elif count < self.swblock*2:
            return int(0 < cnt1 < 3 or 0 < cnt2 < 2) #int(cnt1 + cnt2 > 0)
        else:
            return int(2 < cnt1 or 1 < cnt2) #int(2 < cnt1 < 5 or 1 < cnt2 < 3)

# %%
allresult = dict()
x = 0

# %%
hp = NetworkModel(200,1000,300,1200,8)
result = []
HCprev = []
cond = None
for i in range(80):
    result_,HCprev,cond = hp.process(i, HCprev, cond, verbose = True)
    result.append(result_)
#allresult[x] = result
x += 1
# Out:
# trial 0 stmindex 0 HCprev []
# HCprev []
# think 0-0 [222]
# plan 1 [] 2
# init 1 2
# memo 1 0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# pkup [141] 1-0
# choose [1. 2.] [141 208]
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# HCprev [array([208], dtype=int64)]
# think 0-0 [73]
# plan 2 [] 4
# init 2 4
# memo 2 0
# HF2HC [215] 2-0
# HC2HF [215] 2-0
# pkup [215] 2-0
# choose [2. 4.] [215 142]
# HC2HF [208] 2-0
# HF2HC [215] 2-0
# HC2HF [215] 2-0
# HCprev [array([142], dtype=int64)]
# think 0-0 [282]
# plan 4 [] 1
# init 4 1
# memo 4 0
# HF2HC [218] 4-0
# HC2HF [218] 4-0
# pkup [218] 4-0
# choose [4. 1.] [218  42]
# HC2HF [142] 4-0
# HF2HC [218] 4-0
# HC2HF [218] 4-0
# check trans [4.0] {}
# ['c:1', 'n:2.0', 'e:0.0', 'i:[1.0]', 'c:[0.0]', 'p:[1.0, 2.0]', 'H:[141 208]', 'a:1-0', 'r:0']
# ['c:2', 'n:4.0', 'e:0.0', 'i:[2.0]', 'c:[0.0]', 'p:[2.0, 4.0]', 'H:[208 215 142]', 'a:2-0', 'r:0']
# ['c:4', 'n:1', 'e:0.0', 'i:[4.0, 1.0]', 'c:[0.0, -1.0]', 'p:[4.0, 1.0]', 'H:[142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 1 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# choose [1. 2.] [141 208]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# HCprev [array([141], dtype=int64), array([208], dtype=int64)]
# think 2-0 [215]
# choose [2. 4.] [215 142 218  42]
# HC2HF [208] 2-0
# HF2HC [215] 2-0
# HC2HF [215] 2-0
# check trans [1.0, 2.0, 4.0, 1.0] {}
# ['c:1', 'n:2.0', 'e:0.0', 'i:[1.0, 2.0]', 'c:[0.0, 0.0]', 'p:[1.0, 2.0]', 'H:[ 42 141 208]', 'a:1-0', 'r:0']
# ['c:2', 'n:4.0', 'e:0.15', 'i:[2.0, 4.0]', 'c:[0.0, 0.0]', 'p:[2.0, 4.0]', 'H:[141 208 215 142 218  42]', 'a:2-0', 'r:0']
# ['c:4', 'n:1', 'e:0.15', 'i:[2.0, 4.0]', 'c:[0.0, 0.0]', 'p:[2.0, 4.0]', 'H:[141 208 215 142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 2 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# check trans [1.0, 2.0, 4.0, 1.0] {}
# ['c:1', 'n:4.0', 'e:0.27749999999999997', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.27749999999999997', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 3 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# check trans [1.0, 2.0, 4.0, 1.0] {}
# ['c:1', 'n:4.0', 'e:0.38587499999999997', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.38587499999999997', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 4 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# check trans [1.0, 2.0, 4.0, 1.0] {}
# ['c:1', 'n:4.0', 'e:0.47799375', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.47799375', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 5 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# check trans [1.0, 2.0, 4.0, 1.0] {}
# ['c:1', 'n:4.0', 'e:0.5562946875', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.5562946875', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 6 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# check trans [1.0, 2.0, 4.0, 1.0] {}
# ['c:1', 'n:4.0', 'e:0.622850484375', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.622850484375', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 7 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# check trans [1.0, 2.0, 4.0, 1.0] {}
# ['c:1', 'n:4.0', 'e:0.67942291171875', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.67942291171875', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 8 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['1.0-0', '2.0-0', '4.0-0']
# check trans [1.0, 2.0, 4.0, 1.0] {}
# ['c:1', 'n:4.0', 'e:0.7275094749609375', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.7275094749609375', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 9 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['1.0-0', '2.0-0', '4.0-0']
# check trans [1.0, 2.0, 4.0, 1.0] {}
# ['c:1', 'n:4.0', 'e:0.7683830537167969', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.7683830537167969', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 10 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['1.0-0', '2.0-0', '4.0-0']
# check trans [1.0, 2.0, 4.0, 1.0] {}
# ['c:1', 'n:4.0', 'e:0.8031255956592774', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.8031255956592774', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 11 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['1.0-0', '2.0-0', '4.0-0']
# check trans [1.0, 2.0, 4.0, 1.0] {}
# ['c:1', 'n:4.0', 'e:0.8326567563103858', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.8326567563103858', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 12 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['1.0-0', '2.0-0', '4.0-0']
# check trans [1.0, 2.0, 4.0, 1.0] {}
# ['c:1', 'n:4.0', 'e:0.857758242863828', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.857758242863828', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 13 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['1.0-0', '2.0-0', '4.0-0']
# check trans [1.0, 2.0, 4.0, 1.0] {}
# ['c:1', 'n:4.0', 'e:0.8790945064342538', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.8790945064342538', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 14 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['1.0-0', '2.0-0', '4.0-0']
# check trans [1.0, 2.0, 4.0, 1.0] {}
# ['c:1', 'n:4.0', 'e:0.8972303304691157', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.8972303304691157', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 15 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['1.0-0', '2.0-0', '4.0-0']
# check trans [1.0, 2.0, 4.0, 1.0] {}
# ['c:1', 'n:4.0', 'e:0.9126457808987484', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9126457808987484', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 16 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['1.0-0', '2.0-0', '4.0-0']
# check trans [1.0, 2.0, 4.0, 1.0] {}
# ['c:1', 'n:4.0', 'e:0.9257489137639361', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9257489137639361', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 17 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['1.0-0', '2.0-0', '4.0-0']
# check trans [1.0, 2.0, 4.0, 1.0] {}
# ['c:1', 'n:4.0', 'e:0.9368865766993457', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9368865766993457', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 18 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['1.0-0', '2.0-0', '4.0-0']
# check trans [1.0, 2.0, 4.0, 1.0] {}
# ['c:1', 'n:4.0', 'e:0.9463535901944439', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9463535901944439', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 19 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['1.0-0', '2.0-0', '4.0-0']
# check trans [1.0, 2.0, 4.0, 1.0] {}
# ['c:1', 'n:4.0', 'e:0.9544005516652773', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9544005516652773', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:4-0', 'r:1', "p:['1-0', '2-0', '4-0']"]
#
# trial 20 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# set NG [4. 0.] {(4.0, 0.0): 1.0}
# check trans [1.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:4.0', 'e:0.9612404689154856', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9612404689154856', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[ 42 141 208 215 142 218  42]', 'a:4-0', 'r:0', "p:['1-0', '2-0', '4-0']"]
#
# trial 21 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# plan 2 [4] 3
# actremapping [141 208 215 142] [141 208 215 222]
# choose [1. 2. 3.] [141 208 215 222]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# HCprev [array([222], dtype=int64)]
# think 0-0 [296]
# plan 3 [] 2
# init 3 2
# memo 3 0
# HF2HC [15] 3-0
# HC2HF [15] 3-0
# pkup [15] 3-0
# choose [3. 2.] [15 77]
# HC2HF [222] 3-0
# HF2HC [15] 3-0
# HC2HF [15] 3-0
# HCprev [array([77], dtype=int64)]
# think 0-0 [193]
# plan 2 [] 4
# init 2 4
# memo 2 1
# HF2HC [33] 2-1
# HC2HF [33] 2-1
# pkup [33] 2-1
# choose [2. 4.] [33 66]
# HC2HF [77] 2-1
# HF2HC [33] 2-1
# HC2HF [33] 2-1
# HCprev [array([66], dtype=int64)]
# think 0-0 [291]
# plan 4 [] 1
# init 4 1
# memo 4 1
# HF2HC [114] 4-1
# HC2HF [114] 4-1
# pkup [114] 4-1
# choose [4. 1.] [114 153]
# HC2HF [66] 4-1
# HF2HC [114] 4-1
# HC2HF [114] 4-1
# check trans [4.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:3.0', 'e:0', 'i:[1.0, 2.0]', 'c:[0.0, 0.0]', 'p:[1.0, 2.0, 3.0]', 'H:[ 42 141 208 215 222]', 'a:1-0', 'r:0']
# ['c:3', 'n:2.0', 'e:0.0', 'i:[3.0]', 'c:[0.0]', 'p:[3.0, 2.0]', 'H:[222  15  77]', 'a:3-0', 'r:0']
# ['c:2', 'n:4.0', 'e:0.0', 'i:[2.0]', 'c:[1.0]', 'p:[2.0, 4.0]', 'H:[77 33 66]', 'a:2-1', 'r:0']
# ['c:4', 'n:1', 'e:0.0', 'i:[4.0, 1.0]', 'c:[1.0, -1.0]', 'p:[4.0, 1.0]', 'H:[ 66 114 153]', 'a:4-1', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 22 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# choose [1. 2. 3.] [141 208 215 222]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# HCprev [array([141], dtype=int64), array([208], dtype=int64), array([215], dtype=int64), array([222], dtype=int64)]
# think 3-0 [15]
# choose [3. 2.] [15 77]
# HC2HF [222] 3-0
# HF2HC [15] 3-0
# HC2HF [15] 3-0
# HCprev [array([15], dtype=int64), array([77], dtype=int64)]
# think 2-1 [33]
# choose [2. 4.] [ 33  66 114 153]
# HC2HF [77] 2-1
# HF2HC [33] 2-1
# HC2HF [33] 2-1
# check trans [1.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:3.0', 'e:0.0', 'i:[1.0, 2.0, 3.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 3.0]', 'H:[153 141 208 215 222]', 'a:1-0', 'r:0']
# ['c:3', 'n:2.0', 'e:0.0', 'i:[3.0, 2.0]', 'c:[0.0, 1.0]', 'p:[3.0, 2.0]', 'H:[141 208 215 222  15  77]', 'a:3-0', 'r:0']
# ['c:2', 'n:4.0', 'e:0.15', 'i:[2.0, 4.0]', 'c:[1.0, 1.0]', 'p:[2.0, 4.0]', 'H:[ 15  77  33  66 114 153]', 'a:2-1', 'r:0']
# ['c:4', 'n:1', 'e:0.15', 'i:[2.0, 4.0]', 'c:[1.0, 1.0]', 'p:[2.0, 4.0]', 'H:[ 15  77  33  66 114 153]', 'a:4-1', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 23 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3.] [141 208 215 222]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# HCprev [array([141], dtype=int64), array([208], dtype=int64), array([215], dtype=int64), array([222], dtype=int64)]
# think 3-0 [15]
# choose [3. 2. 4.] [ 15  77  33  66 114 153]
# HC2HF [222] 3-0
# HF2HC [15] 3-0
# HC2HF [15] 3-0
# check trans [1.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:3.0', 'e:0.0', 'i:[1.0, 2.0, 3.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 3.0]', 'H:[153 141 208 215 222]', 'a:1-0', 'r:0']
# ['c:3', 'n:4.0', 'e:0.27749999999999997', 'i:[3.0, 2.0, 4.0]', 'c:[0.0, 1.0, 1.0]', 'p:[3.0, 2.0, 4.0]', 'H:[141 208 215 222  15  77  33  66 114 153]', 'a:3-0', 'r:0']
# ['c:4', 'n:1', 'e:0.27749999999999997', 'i:[3.0, 2.0, 4.0]', 'c:[0.0, 1.0, 1.0]', 'p:[3.0, 2.0, 4.0]', 'H:[141 208 215 222  15  77  33  66 114 153]', 'a:4-1', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 24 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 4.] [141 208 215 222  15  77  33  66 114 153]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# check trans [1.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:4.0', 'e:0.38587499999999997', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.38587499999999997', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:4-1', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 25 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 4.] [141 208 215 222  15  77  33  66 114 153]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# check trans [1.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:4.0', 'e:0.47799375', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.47799375', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:4-1', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 26 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 4.] [141 208 215 222  15  77  33  66 114 153]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# check trans [1.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:4.0', 'e:0.5562946875', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.5562946875', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:4-1', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 27 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 4.] [141 208 215 222  15  77  33  66 114 153]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# check trans [1.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:4.0', 'e:0.622850484375', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.622850484375', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:4-1', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 28 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 4.] [141 208 215 222  15  77  33  66 114 153]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# check trans [1.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:4.0', 'e:0.67942291171875', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.67942291171875', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:4-1', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 29 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 4.] [141 208 215 222  15  77  33  66 114 153]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-0', '2.0-1', '4.0-1', '1.0-0']
# check trans [1.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:4.0', 'e:0.7275094749609375', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.7275094749609375', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:4-1', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 30 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 4.] [141 208 215 222  15  77  33  66 114 153]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-0', '2.0-1', '4.0-1', '1.0-0']
# check trans [1.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:4.0', 'e:0.7683830537167969', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.7683830537167969', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:4-1', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 31 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 4.] [141 208 215 222  15  77  33  66 114 153]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-0', '2.0-1', '4.0-1', '1.0-0']
# check trans [1.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:4.0', 'e:0.8031255956592774', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.8031255956592774', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:4-1', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 32 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 4.] [141 208 215 222  15  77  33  66 114 153]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-0', '2.0-1', '4.0-1', '1.0-0']
# check trans [1.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:4.0', 'e:0.8326567563103858', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.8326567563103858', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:4-1', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 33 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 4.] [141 208 215 222  15  77  33  66 114 153]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-0', '2.0-1', '4.0-1', '1.0-0']
# check trans [1.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:4.0', 'e:0.857758242863828', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.857758242863828', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:4-1', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 34 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 4.] [141 208 215 222  15  77  33  66 114 153]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-0', '2.0-1', '4.0-1', '1.0-0']
# check trans [1.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:4.0', 'e:0.8790945064342538', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.8790945064342538', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:4-1', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 35 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 4.] [141 208 215 222  15  77  33  66 114 153]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-0', '2.0-1', '4.0-1', '1.0-0']
# check trans [1.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:4.0', 'e:0.8972303304691157', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.8972303304691157', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:4-1', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 36 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 4.] [141 208 215 222  15  77  33  66 114 153]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-0', '2.0-1', '4.0-1', '1.0-0']
# check trans [1.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:4.0', 'e:0.9126457808987484', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9126457808987484', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:4-1', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 37 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 4.] [141 208 215 222  15  77  33  66 114 153]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-0', '2.0-1', '4.0-1', '1.0-0']
# check trans [1.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:4.0', 'e:0.9257489137639361', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9257489137639361', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:4-1', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 38 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 4.] [141 208 215 222  15  77  33  66 114 153]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-0', '2.0-1', '4.0-1', '1.0-0']
# check trans [1.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:4.0', 'e:0.9368865766993457', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9368865766993457', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:4-1', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 39 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 4.] [141 208 215 222  15  77  33  66 114 153]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-0', '2.0-1', '4.0-1', '1.0-0']
# check trans [1.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.0}
# ['c:1', 'n:4.0', 'e:0.9463535901944439', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9463535901944439', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:4-1', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 40 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 4.] [141 208 215 222  15  77  33  66 114 153]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# set NG [4. 1.] {(4.0, 0.0): 0.7, (4.0, 1.0): 1.0}
# check trans [1.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 0.7, (4.0, 1.0): 1.0}
# ['c:1', 'n:4.0', 'e:0.9544005516652773', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9544005516652773', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[153 141 208 215 222  15  77  33  66 114 153]', 'a:4-1', 'r:0', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 41 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 4.] [141 208 215 142 218  42]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# set NG [4. 0.] {(4.0, 0.0): 1.49, (4.0, 1.0): 0.7}
# check trans [1.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.49, (4.0, 1.0): 0.7}
# ['c:1', 'n:4.0', 'e:0.8170543985781629', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[153 141 208 215 142 218  42]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.8170543985781629', 'i:[1.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0]', 'p:[1.0, 2.0, 4.0]', 'H:[153 141 208 215 142 218  42]', 'a:4-0', 'r:0', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 42 stmindex 0 HCprev 42
# HCprev [array([42], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 4.] [141 208 215 222  15  77  33  66 114 153]
# HC2HF [42] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# set NG [4. 1.] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# check trans [1.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.8112404689154857', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[ 42 141 208 215 222  15  77  33  66 114 153]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.8112404689154857', 'i:[1.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 4.0]', 'H:[ 42 141 208 215 222  15  77  33  66 114 153]', 'a:4-1', 'r:0', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1']"]
#
# trial 43 stmindex 0 HCprev 153
# HCprev [array([153], dtype=int64)]
# think 1-0 [141]
# plan 2 [4] 3
# actremapping [141 208 215 222  15  77  33  66] [141 208 215 222  15  77  33 267]
# choose [1. 2. 3. 2. 3.] [141 208 215 222  15  77  33 267]
# HC2HF [153] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# HCprev [array([267], dtype=int64)]
# think 0-0 [201]
# plan 3 [] 2
# init 3 2
# memo 3 1
# HF2HC [230] 3-1
# HC2HF [230] 3-1
# pkup [230] 3-1
# choose [3. 2.] [230 212]
# HC2HF [267] 3-1
# HF2HC [230] 3-1
# HC2HF [230] 3-1
# HCprev [array([212], dtype=int64)]
# think 0-0 [74]
# plan 2 [] 4
# init 2 4
# memo 2 2
# HF2HC [192] 2-2
# HC2HF [192] 2-2
# pkup [192] 2-2
# choose [2. 4.] [192  60]
# HC2HF [212] 2-2
# HF2HC [192] 2-2
# HC2HF [192] 2-2
# HCprev [array([60], dtype=int64)]
# think 0-0 [7]
# plan 4 [] 1
# init 4 1
# memo 4 2
# HF2HC [204] 4-2
# HC2HF [204] 4-2
# pkup [204] 4-2
# choose [4. 1.] [204 248]
# HC2HF [60] 4-2
# HF2HC [204] 4-2
# HC2HF [204] 4-2
# check trans [4.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:3.0', 'e:0', 'i:[1.0, 2.0, 3.0, 2.0]', 'c:[0.0, 0.0, 0.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0]', 'H:[153 141 208 215 222  15  77  33 267]', 'a:1-0', 'r:0']
# ['c:3', 'n:2.0', 'e:0.0', 'i:[3.0]', 'c:[1.0]', 'p:[3.0, 2.0]', 'H:[267 230 212]', 'a:3-1', 'r:0']
# ['c:2', 'n:4.0', 'e:0.0', 'i:[2.0]', 'c:[2.0]', 'p:[2.0, 4.0]', 'H:[212 192  60]', 'a:2-2', 'r:0']
# ['c:4', 'n:1', 'e:0.0', 'i:[4.0, 1.0]', 'c:[2.0, -1.0]', 'p:[4.0, 1.0]', 'H:[ 60 204 248]', 'a:4-2', 'r:0', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 44 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# external stm 1
# think 1-0 [141]
# choose [1. 2. 3. 2. 3.] [141 208 215 222  15  77  33 267]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# HCprev [array([141], dtype=int64), array([208], dtype=int64), array([215], dtype=int64), array([222], dtype=int64), array([15], dtype=int64), array([77], dtype=int64), array([33], dtype=int64), array([267], dtype=int64)]
# think 3-1 [230]
# choose [3. 2.] [230 212]
# HC2HF [267] 3-1
# HF2HC [230] 3-1
# HC2HF [230] 3-1
# HCprev [array([230], dtype=int64), array([212], dtype=int64)]
# think 2-2 [192]
# choose [2. 4.] [192  60]
# HC2HF [212] 2-2
# HF2HC [192] 2-2
# HC2HF [192] 2-2
# HCprev [array([192], dtype=int64), array([60], dtype=int64)]
# think 4-2 [204]
# choose [4. 1.] [204 248]
# HC2HF [60] 4-2
# HF2HC [204] 4-2
# HC2HF [204] 4-2
# check trans [1.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:3.0', 'e:0.0', 'i:[1.0, 2.0, 3.0, 2.0, 3.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0]', 'H:[248 141 208 215 222  15  77  33 267]', 'a:1-0', 'r:0']
# ['c:3', 'n:2.0', 'e:0.0', 'i:[3.0, 2.0]', 'c:[1.0, 2.0]', 'p:[3.0, 2.0]', 'H:[141 208 215 222  15  77  33 267 230 212]', 'a:3-1', 'r:0']
# ['c:2', 'n:4.0', 'e:0.0', 'i:[2.0, 4.0]', 'c:[2.0, 2.0]', 'p:[2.0, 4.0]', 'H:[230 212 192  60]', 'a:2-2', 'r:0']
# ['c:4', 'n:1', 'e:0.0', 'i:[4.0, 1.0]', 'c:[2.0, -1.0]', 'p:[4.0, 1.0]', 'H:[192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 45 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3.] [141 208 215 222  15  77  33 267]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# HCprev [array([141], dtype=int64), array([208], dtype=int64), array([215], dtype=int64), array([222], dtype=int64), array([15], dtype=int64), array([77], dtype=int64), array([33], dtype=int64), array([267], dtype=int64)]
# think 3-1 [230]
# choose [3. 2.] [230 212]
# HC2HF [267] 3-1
# HF2HC [230] 3-1
# HC2HF [230] 3-1
# HCprev [array([230], dtype=int64), array([212], dtype=int64)]
# think 2-2 [192]
# choose [2. 4.] [192  60 204 248]
# HC2HF [212] 2-2
# HF2HC [192] 2-2
# HC2HF [192] 2-2
# check trans [1.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:3.0', 'e:0.0', 'i:[1.0, 2.0, 3.0, 2.0, 3.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0]', 'H:[248 141 208 215 222  15  77  33 267]', 'a:1-0', 'r:0']
# ['c:3', 'n:2.0', 'e:0.0', 'i:[3.0, 2.0]', 'c:[1.0, 2.0]', 'p:[3.0, 2.0]', 'H:[141 208 215 222  15  77  33 267 230 212]', 'a:3-1', 'r:0']
# ['c:2', 'n:4.0', 'e:0.15', 'i:[2.0, 4.0]', 'c:[2.0, 2.0]', 'p:[2.0, 4.0]', 'H:[230 212 192  60 204 248]', 'a:2-2', 'r:0']
# ['c:4', 'n:1', 'e:0.15', 'i:[2.0, 4.0]', 'c:[2.0, 2.0]', 'p:[2.0, 4.0]', 'H:[230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 46 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3.] [141 208 215 222  15  77  33 267]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# HCprev [array([141], dtype=int64), array([208], dtype=int64), array([215], dtype=int64), array([222], dtype=int64), array([15], dtype=int64), array([77], dtype=int64), array([33], dtype=int64), array([267], dtype=int64)]
# think 3-1 [230]
# choose [3. 2. 4.] [230 212 192  60 204 248]
# HC2HF [267] 3-1
# HF2HC [230] 3-1
# HC2HF [230] 3-1
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:3.0', 'e:0.0', 'i:[1.0, 2.0, 3.0, 2.0, 3.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0]', 'H:[248 141 208 215 222  15  77  33 267]', 'a:1-0', 'r:0']
# ['c:3', 'n:4.0', 'e:0.27749999999999997', 'i:[3.0, 2.0, 4.0]', 'c:[1.0, 2.0, 2.0]', 'p:[3.0, 2.0, 4.0]', 'H:[141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:3-1', 'r:0']
# ['c:4', 'n:1', 'e:0.27749999999999997', 'i:[3.0, 2.0, 4.0]', 'c:[1.0, 2.0, 2.0]', 'p:[3.0, 2.0, 4.0]', 'H:[141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 47 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.38587499999999997', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.38587499999999997', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 48 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.47799375', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.47799375', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 49 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.5562946875', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.5562946875', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 50 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.622850484375', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.622850484375', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 51 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.67942291171875', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.67942291171875', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 52 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.7275094749609375', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.7275094749609375', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 53 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.7683830537167969', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.7683830537167969', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 54 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.8031255956592774', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.8031255956592774', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 55 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.8326567563103858', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.8326567563103858', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 56 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.857758242863828', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.857758242863828', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 57 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.8790945064342538', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.8790945064342538', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 58 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.8972303304691157', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.8972303304691157', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 59 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.9126457808987484', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ...
# ['c:1', 'n:4.0', 'e:0.9544005516652773', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9544005516652773', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 64 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.9612404689154856', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9612404689154856', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 65 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.9670543985781628', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9670543985781628', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 66 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.9719962387914384', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9719962387914384', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 67 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.9761968029727226', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9761968029727226', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 68 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.9797672825268142', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9797672825268142', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 69 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.9828021901477921', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9828021901477921', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 70 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.9853818616256234', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9853818616256234', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 71 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.9875745823817799', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9875745823817799', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 72 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.9894383950245129', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9894383950245129', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 73 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.9910226357708359', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9910226357708359', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 74 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.9923692404052106', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9923692404052106', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 75 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.993513854344429', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.993513854344429', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 76 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.9944867761927646', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9944867761927646', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 77 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.99531375976385', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.99531375976385', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 78 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.9960166957992724', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9960166957992724', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]
#
# trial 79 stmindex 0 HCprev 248
# HCprev [array([248], dtype=int64)]
# think 1-0 [141]
# choose [1. 2. 3. 2. 3. 2. 4.] [141 208 215 222  15  77  33 267 230 212 192  60 204 248]
# HC2HF [248] 1-0
# HF2HC [141] 1-0
# HC2HF [141] 1-0
# tested ['4.0-0', '3.0-0', '2.0-2', '2.0-0', '2.0-1', '4.0-1', '1.0-0', '3.0-1', '4.0-2']
# check trans [1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0, 1.0] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# ['c:1', 'n:4.0', 'e:0.9966141914293816', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:1-0', 'r:0']
# ['c:4', 'n:1', 'e:0.9966141914293816', 'i:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'c:[0.0, 0.0, 0.0, 1.0, 1.0, 2.0, 2.0]', 'p:[1.0, 2.0, 3.0, 2.0, 3.0, 2.0, 4.0]', 'H:[248 141 208 215 222  15  77  33 267 230 212 192  60 204 248]', 'a:4-2', 'r:1', "p:['1-0', '2-0', '4-0', '3-0', '2-1', '4-1', '3-1', '2-2', '4-2']"]

# %%
num = 40
trialnum = 80
allresult = dict() #np.zeros((num,trialnum))*np.nan
x = 0
errcounter = 0
while x < num:
    print(x)
    hp = NetworkModel(200,1000,300,1200,8)
    result = []
    HCprev = []
    cond = None
    try:
        for i in range(trialnum):
            result_,HCprev,cond = hp.process(i, HCprev, cond,verbose = False)
            result.append(result_)
        allresult[x] = result
    except:
        print("error",x)
        allresult[x] = result
        errcounter += 1
    x += 1
print(errcounter)
# Out:
# 0
# init 1 2
# init 2 3
# init 3 2
# init 2 4
# init 4 1
# actremapping [157   7] [157 175]
# init 4 1
# set NG [4. 1.] {(4.0, 1.0): 1.0}
# actremapping [79 47] [79 52]
# init 3 2
# init 2 4
# init 4 1
# actremapping [ 23 215] [ 23 170]
# init 3 2
# init 2 4
# init 4 1
# actremapping [54 58] [ 54 239]
# init 3 2
# init 2 4
# init 4 1
# actremapping [275 237] [275 120]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 1.] {(4.0, 1.0): 1.0}
# init 2 4
# init 4 1
# 1
# init 1 2
# init 2 3
# init 3 2
# init 2 4
# init 4 1
# actremapping [82 55] [ 82 155]
# init 3 2
# init 2 4
# init 4 1
# actremapping [ 8 34] [ 8 14]
# init 3 2
# init 2 4
# init 4 1
# actremapping [198 165] [198  29]
# init 4 1
# set NG [4. 3.] {(4.0, 3.0): 1.0}
# set NG [4. 0.] {(4.0, 0.0): 1.0, (4.0, 3.0): 0.7}
# set NG [4. 3.] {(4.0, 0.0): 0.7, (4.0, 3.0): 1.49}
# set NG [4. 0.] {(4.0, 0.0): 1.49, (4.0, 3.0): 1.043}
# set NG [4. 3.] {(4.0, 0.0): 1.043, (4.0, 3.0): 1.7300999999999997}
# set NG [4. 0.] {(4.0, 0.0): 1.7300999999999997, (4.0, 3.0): 1.2110699999999996}
# set NG [4. 3.] {(4.0, 0.0): 1.2110699999999996, (4.0, 3.0): 1.8477489999999999}
# set NG [4. 0.] {(4.0, 0.0): 1.8477489999999999, (4.0, 3.0): 1.2934242999999999}
# set NG [4. 3.] {(4.0, 0.0): 1.2934242999999999, (4.0, 3.0): 1.9053970099999997}
# set NG [4. 0.] {(4.0, 0.0): 1.9053970099999997, (4.0, 3.0): 1.3337779069999998}
# set NG [4. 3.] {(4.0, 0.0): 1.3337779069999998, (4.0, 3.0): 1.9336445348999998}
# set NG [4. 0.] {(4.0, 0.0): 1.9336445348999998, (4.0, 3.0): 1.3535511744299997}
# set NG [4. 3.] {(4.0, 0.0): 1.3535511744299997, (4.0, 3.0): 1.9474858221009996}
# set NG [4. 0.] {(4.0, 0.0): 1.9474858221009996, (4.0, 3.0): 1.3632400754706997}
# set NG [4. 3.] {(4.0, 0.0): 1.3632400754706997, (4.0, 3.0): 1.9542680528294896}
# set NG [4. 0.] {(4.0, 0.0): 1.9542680528294896, (4.0, 3.0): 1.3679876369806425}
# set NG [4. 3.] {(4.0, 0.0): 1.3679876369806425, (4.0, 3.0): 1.9575913458864496}
# 2
# init 1 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.0}
# actremapping [138 184 280 192] [138 184 280 105]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 1.] {(4.0, 0.0): 0.7, (4.0, 1.0): 1.0}
# set NG [4. 0.] {(4.0, 0.0): 1.49, (4.0, 1.0): 0.7}
# set NG [4. 0.] {(4.0, 0.0): 2.043, (4.0, 1.0): 0.48999999999999994}
# set NG [4. 1.] {(4.0, 0.0): 1.4301, (4.0, 1.0): 1.343}
# actremapping [138 184 280 105 111  92 257  45] [138 184 280 105 111  92 257  95]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 1.] {(4.0, 0.0): 1.00107, (4.0, 1.0): 1.9401}
# set NG [4. 0.] {(4.0, 0.0): 1.7007489999999998, (4.0, 1.0): 1.3580699999999999}
# set NG [4. 1.] {(4.0, 0.0): 1.1905242999999999, (4.0, 1.0): 1.9506489999999999}
# set NG [4. 0.] {(4.0, 0.0): 1.83336701, (4.0, 1.0): 1.3654543}
# set NG [4. 1.] {(4.0, 0.0): 1.283356907, (4.0, 1.0): 1.9558180099999998}
# set NG [4. 0.] {(4.0, 0.0): 1.8983498348999999, (4.0, 1.0): 1.3690726069999997}
# 3
# init 1 2
# init 2 3
# init 3 2
# init 2 4
# init 4 1
# actremapping [271  28] [271 249]
# init 3 2
# init 2 4
# init 4 1
# actremapping [227 201] [227  99]
# init 3 2
# init 2 4
# init 4 1
# actremapping [236  33] [236 118]
# init 4 1
# set NG [4. 3.] {(4.0, 3.0): 1.0}
# actremapping [ 0 34] [  0 233]
# init 3 2
# init 2 4
# init 4 1
# actremapping [87 54] [ 87 262]
# init 3 2
# init 2 4
# init 4 1
# init 2 4
# init 4 1
# set NG [4. 3.] {(4.0, 3.0): 1.0}
# 4
# init 1 2
# init 2 3
# init 3 2
# init 2 4
# init 4 1
# actremapping [ 78 135] [78 71]
# init 3 2
# init 2 4
# init 4 1
# actremapping [47 94] [ 47 157]
# init 4 1
# set NG [4. 2.] {(4.0, 2.0): 1.0}
# set NG [4. 0.] {(4.0, 0.0): 1.0, (4.0, 2.0): 0.7}
# set NG [4. 2.] {(4.0, 0.0): 0.7, (4.0, 2.0): 1.49}
# set NG [4. 0.] {(4.0, 0.0): 1.49, (4.0, 2.0): 1.043}
# set NG [4. 2.] {(4.0, 0.0): 1.043, (4.0, 2.0): 1.7300999999999997}
# set NG [4. 0.] {(4.0, 0.0): 1.7300999999999997, (4.0, 2.0): 1.2110699999999996}
# set NG [4. 2.] {(4.0, 0.0): 1.2110699999999996, (4.0, 2.0): 1.8477489999999999}
# set NG [4. 0.] {(4.0, 0.0): 1.8477489999999999, (4.0, 2.0): 1.2934242999999999}
# set NG [4. 2.] {(4.0, 0.0): 1.2934242999999999, (4.0, 2.0): 1.9053970099999997}
# set NG [4. 0.] {(4.0, 0.0): 1.9053970099999997, (4.0, 2.0): 1.3337779069999998}
# set NG [4. 2.] {(4.0, 0.0): 1.3337779069999998, (4.0, 2.0): 1.9336445348999998}
# set NG [4. 0.] {(4.0, 0.0): 1.9336445348999998, (4.0, 2.0): 1.3535511744299997}
# 5
# init 1 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.0}
# actremapping [ 47 117  73  90] [ 47 117  73  78]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 1.] {(4.0, 0.0): 0.7, (4.0, 1.0): 1.0}
# set NG [4. 0.] {(4.0, 0.0): 1.49, (4.0, 1.0): 0.7}
# set NG [4. 1.] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# actremapping [ 47 117  73  78 259 219 128 108] [ 47 117  73  78 259 219 128 156]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.7300999999999997, (4.0, 1.0): 1.043}
# set NG [4. 1.] {(4.0, 0.0): 1.2110699999999996, (4.0, 1.0): 1.7300999999999997}
# set NG [4. 0.] {(4.0, 0.0): 1.8477489999999999, (4.0, 1.0): 1.2110699999999996}
# set NG [4. 1.] {(4.0, 0.0): 1.2934242999999999, (4.0, 1.0): 1.8477489999999999}
# set NG [4. 0.] {(4.0, 0.0): 1.9053970099999997, (4.0, 1.0): 1.2934242999999999}
# set NG [4. 1.] {(4.0, 0.0): 1.3337779069999998, (4.0, 1.0): 1.9053970099999997}
# 6
# init 1 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.0}
# actremapping [ 53 251 107 157] [ 53 251 107 217]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 1.] {(4.0, 0.0): 0.7, (4.0, 1.0): 1.0}
# set NG [4. 0.] {(4.0, 0.0): 1.49, (4.0, 1.0): 0.7}
# set NG [4. 1.] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# actremapping [ 53 251 107 217 280  93  52 236] [ 53 251 107 217 280  93  52  92]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.7300999999999997, (4.0, 1.0): 1.043}
# set NG [4. 1.] {(4.0, 0.0): 1.2110699999999996, (4.0, 1.0): 1.7300999999999997}
# set NG [4. 0.] {(4.0, 0.0): 1.8477489999999999, (4.0, 1.0): 1.2110699999999996}
# set NG [4. 1.] {(4.0, 0.0): 1.2934242999999999, (4.0, 1.0): 1.8477489999999999}
# 7
# init 1 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.0}
# actremapping [24 37  3  1] [ 24  37   3 117]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 1.] {(4.0, 0.0): 0.7, (4.0, 1.0): 1.0}
# set NG [4. 0.] {(4.0, 0.0): 1.49, (4.0, 1.0): 0.7}
# set NG [4. 1.] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# set NG [4. 0.] {(4.0, 0.0): 1.7300999999999997, (4.0, 1.0): 1.043}
# actremapping [ 24  37   3 117 126 219 242   2] [ 24  37   3 117 126 219 242  60]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 1.] {(4.0, 0.0): 1.2110699999999996, (4.0, 1.0): 1.7300999999999997}
# set NG [4. 0.] {(4.0, 0.0): 1.8477489999999999, (4.0, 1.0): 1.2110699999999996}
# set NG [4. 1.] {(4.0, 0.0): 1.2934242999999999, (4.0, 1.0): 1.8477489999999999}
# set NG [4. 0.] {(4.0, 0.0): 1.9053970099999997, (4.0, 1.0): 1.2934242999999999}
# set NG [4. 1.] {(4.0, 0.0): 1.3337779069999998, (4.0, 1.0): 1.9053970099999997}
# set NG [4. 0.] {(4.0, 0.0): 1.9336445348999998, (4.0, 1.0): 1.3337779069999998}
# set NG [4. 1.] {(4.0, 0.0): 1.3535511744299997, (4.0, 1.0): 1.9336445348999998}
# set NG [4. 0.] {(4.0, 0.0): 1.9474858221009996, (4.0, 1.0): 1.3535511744299997}
# set NG [4. 1.] {(4.0, 0.0): 1.3632400754706997, (4.0, 1.0): 1.9474858221009996}
# set NG [4. 0.] {(4.0, 0.0): 1.9542680528294896, (4.0, 1.0): 1.3632400754706997}
# set NG [4. 1.] {(4.0, 0.0): 1.3679876369806425, (4.0, 1.0): 1.9542680528294896}
0): 1.8477489999999999}
# set NG [4. 0.] {(4.0, 0.0): 1.9053970099999997, (4.0, 1.0): 1.2934242999999999}
# set NG [4. 1.] {(4.0, 0.0): 1.3337779069999998, (4.0, 1.0): 1.9053970099999997}
# set NG [4. 0.] {(4.0, 0.0): 1.9336445348999998, (4.0, 1.0): 1.3337779069999998}
# 11
# init 1 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.0}
# actremapping [ 55 186  50 211] [ 55 186  50   0]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 1.] {(4.0, 0.0): 0.7, (4.0, 1.0): 1.0}
# set NG [4. 0.] {(4.0, 0.0): 1.49, (4.0, 1.0): 0.7}
# set NG [4. 1.] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# actremapping [ 55 186  50   0  30  62  56   8] [ 55 186  50   0  30  62  56  63]
# init 3 2
# init 2 4
# init 4 1
# actremapping [ 11 100] [11 95]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.7300999999999997, (4.0, 1.0): 1.043}
# set NG [4. 1.] {(4.0, 0.0): 1.2110699999999996, (4.0, 1.0): 1.7300999999999997}
# set NG [4. 0.] {(4.0, 0.0): 1.8477489999999999, (4.0, 1.0): 1.2110699999999996}
# set NG [4. 1.] {(4.0, 0.0): 1.2934242999999999, (4.0, 1.0): 1.8477489999999999}
# set NG [4. 0.] {(4.0, 0.0): 1.9053970099999997, (4.0, 1.0): 1.2934242999999999}
# set NG [4. 1.] {(4.0, 0.0): 1.3337779069999998, (4.0, 1.0): 1.9053970099999997}
# set NG [4. 0.] {(4.0, 0.0): 1.9336445348999998, (4.0, 1.0): 1.3337779069999998}
# 12
# init 1 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.0}
# actremapping [255 281 122 218] [255 281 122 184]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 1.] {(4.0, 0.0): 0.7, (4.0, 1.0): 1.0}
# set NG [4. 0.] {(4.0, 0.0): 1.49, (4.0, 1.0): 0.7}
# set NG [4. 1.] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# set NG [4. 0.] {(4.0, 0.0): 1.7300999999999997, (4.0, 1.0): 1.043}
# actremapping [255 281 122 184 246  55 158  17] [255 281 122 184 246  55 158 141]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 1.] {(4.0, 0.0): 1.2110699999999996, (4.0, 1.0): 1.7300999999999997}
# set NG [4. 0.] {(4.0, 0.0): 1.8477489999999999, (4.0, 1.0): 1.2110699999999996}
# set NG [4. 1.] {(4.0, 0.0): 1.2934242999999999, (4.0, 1.0): 1.8477489999999999}
# 13
# init 1 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.0}
# actremapping [172 144 224 171] [172 144 224  82]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 1.] {(4.0, 0.0): 0.7, (4.0, 1.0): 1.0}
# set NG [4. 0.] {(4.0, 0.0): 1.49, (4.0, 1.0): 0.7}
# set NG [4. 1.] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# actremapping [172 144 224  82 274 115 222  42] [172 144 224  82 274 115 222  97]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.7300999999999997, (4.0, 1.0): 1.043}
# set NG [4. 1.] {(4.0, 0.0): 1.2110699999999996, (4.0, 1.0): 1.7300999999999997}
# set NG [4. 0.] {(4.0, 0.0): 1.8477489999999999, (4.0, 1.0): 1.2110699999999996}
# set NG [4. 1.] {(4.0, 0.0): 1.2934242999999999, (4.0, 1.0): 1.8477489999999999}
# set NG [4. 0.] {(4.0, 0.0): 1.9053970099999997, (4.0, 1.0): 1.2934242999999999}
# set NG [4. 1.] {(4.0, 0.0): 1.3337779069999998, (4.0, 1.0): 1.9053970099999997}
# set NG [4. 0.] {(4.0, 0.0): 1.9336445348999998, (4.0, 1.0): 1.3337779069999998}
# 14
# init 1 2
# init 2 3
# init 3 2
# init 2 4
# init 4 1
# actremapping [149  37] [149 142]
# init 4 1
# set NG [4. 1.] {(4.0, 1.0): 1.0}
# set NG [4. 0.] {(4.0, 1.0): 0.7, (4.0, 0.0): 1.0}
# set NG [4. 1.] {(4.0, 1.0): 1.49, (4.0, 0.0): 0.7}
# set NG [4. 0.] {(4.0, 1.0): 1.043, (4.0, 0.0): 1.49}
# actremapping [248 244 149  37 162  74 135  25] [248 244 149  37 162  74 135  88]
# init 3 2
# init 2 3
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 1.] {(4.0, 1.0): 1.7300999999999997, (4.0, 0.0): 1.043}
# set NG [4. 0.] {(4.0, 1.0): 1.2110699999999996, (4.0, 0.0): 1.7300999999999997}
# set NG [4. 1.] {(4.0, 1.0): 1.8477489999999999, (4.0, 0.0): 1.2110699999999996}
# set NG [4. 0.] {(4.0, 1.0): 1.2934242999999999, (4.0, 0.0): 1.8477489999999999}
# set NG [4. 1.] {(4.0, 1.0): 1.9053970099999997, (4.0, 0.0): 1.2934242999999999}
# 15
# init 1 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.0}
# actremapping [264  35 196  41] [264  35 196 145]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 1.] {(4.0, 0.0): 0.7, (4.0, 1.0): 1.0}
# set NG [4. 0.] {(4.0, 0.0): 1.49, (4.0, 1.0): 0.7}
# set NG [4. 1.] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# actremapping [264  35 196 145 127 183 179 239] [264  35 196 145 127 183 179  98]
# init 3 2
# init 2 4
# init 4 1
# actremapping [161  23] [161 150]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.7300999999999997, (4.0, 1.0): 1.043}
# set NG [4. 1.] {(4.0, 0.0): 1.2110699999999996, (4.0, 1.0): 1.7300999999999997}
# set NG [4. 0.] {(4.0, 0.0): 1.8477489999999999, (4.0, 1.0): 1.2110699999999996}
# set NG [4. 1.] {(4.0, 0.0): 1.2934242999999999, (4.0, 1.0): 1.8477489999999999}
# 16
# init 1 2
# init 2 3
# init 3 2
# init 2 4
# init 4 1
# actremapping [ 93 109] [ 93 255]
# init 3 2
# init 2 4
# init 4 1
# actremapping [265  22] [265 181]
# init 3 2
# init 2 4
# init 4 1
# actremapping [150 108] [150 233]
# init 3 2
# init 2 4
# init 4 1
# actremapping [222   8] [222 104]
# init 4 1
# set NG [4. 4.] {(4.0, 4.0): 1.0}
# set NG [4. 0.] {(4.0, 0.0): 1
# init 1 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.0}
# actremapping [ 88  22 104 101] [ 88  22 104 151]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 1.] {(4.0, 0.0): 0.7, (4.0, 1.0): 1.0}
# set NG [4. 0.] {(4.0, 0.0): 1.49, (4.0, 1.0): 0.7}
# set NG [4. 1.] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# actremapping [ 88  22 104 151 177 168 149 150] [ 88  22 104 151 177 168 149 248]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.7300999999999997, (4.0, 1.0): 1.043}
# set NG [4. 1.] {(4.0, 0.0): 1.2110699999999996, (4.0, 1.0): 1.7300999999999997}
# set NG [4. 0.] {(4.0, 0.0): 1.8477489999999999, (4.0, 1.0): 1.2110699999999996}
# set NG [4. 1.] {(4.0, 0.0): 1.2934242999999999, (4.0, 1.0): 1.8477489999999999}
# set NG [4. 0.] {(4.0, 0.0): 1.9053970099999997, (4.0, 1.0): 1.2934242999999999}
# 25
# init 1 2
# init 2 3
# init 3 2
# init 2 4
# init 4 1
# actremapping [ 91 115] [91 34]
# init 3 2
# init 2 4
# init 4 1
# actremapping [142 272] [142 169]
# init 4 1
# set NG [4. 2.] {(4.0, 2.0): 1.0}
# set NG [4. 0.] {(4.0, 0.0): 1.0, (4.0, 2.0): 0.7}
# set NG [4. 2.] {(4.0, 0.0): 0.7, (4.0, 2.0): 1.49}
# set NG [4. 0.] {(4.0, 0.0): 1.49, (4.0, 2.0): 1.043}
# set NG [4. 2.] {(4.0, 0.0): 1.043, (4.0, 2.0): 1.7300999999999997}
# set NG [4. 0.] {(4.0, 0.0): 1.7300999999999997, (4.0, 2.0): 1.2110699999999996}
# set NG [4. 2.] {(4.0, 0.0): 1.2110699999999996, (4.0, 2.0): 1.8477489999999999}
# set NG [4. 0.] {(4.0, 0.0): 1.8477489999999999, (4.0, 2.0): 1.2934242999999999}
# set NG [4. 2.] {(4.0, 0.0): 1.2934242999999999, (4.0, 2.0): 1.9053970099999997}
# 26
# init 1 2
# init 2 3
# init 3 2
# init 2 4
# init 4 1
# actremapping [263 232] [263  76]
# init 4 1
# set NG [4. 1.] {(4.0, 1.0): 1.0}
# set NG [4. 0.] {(4.0, 1.0): 0.7, (4.0, 0.0): 1.0}
# set NG [4. 1.] {(4.0, 1.0): 1.49, (4.0, 0.0): 0.7}
# set NG [4. 0.] {(4.0, 1.0): 1.043, (4.0, 0.0): 1.49}
# set NG [4. 1.] {(4.0, 1.0): 1.7300999999999997, (4.0, 0.0): 1.043}
# actremapping [169 186 263 232  70 288  79 203] [169 186 263 232  70 288  79  31]
# init 3 2
# init 2 3
# init 3 2
# init 2 4
# init 4 1
# actremapping [ 66 135] [ 66 198]
# init 4 1
# set NG [4. 0.] {(4.0, 1.0): 1.2110699999999996, (4.0, 0.0): 1.7300999999999997}
# set NG [4. 1.] {(4.0, 1.0): 1.8477489999999999, (4.0, 0.0): 1.2110699999999996}
# set NG [4. 0.] {(4.0, 1.0): 1.2934242999999999, (4.0, 0.0): 1.8477489999999999}
# 27
# init 1 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.0}
# actremapping [ 18 293  64 225] [ 18 293  64  92]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 1.] {(4.0, 0.0): 0.7, (4.0, 1.0): 1.0}
# set NG [4. 0.] {(4.0, 0.0): 1.49, (4.0, 1.0): 0.7}
# set NG [4. 1.] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# actremapping [ 18 293  64  92 181  36  22 279] [ 18 293  64  92 181  36  22  65]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.7300999999999997, (4.0, 1.0): 1.043}
# set NG [4. 1.] {(4.0, 0.0): 1.2110699999999996, (4.0, 1.0): 1.7300999999999997}
# 28
# init 1 2
# init 2 3
# init 3 2
# init 2 4
# init 4 1
# actremapping [ 93 287] [ 93 135]
# init 3 2
# init 2 4
# init 4 1
# actremapping [198  90] [198 170]
# init 4 1
# set NG [4. 2.] {(4.0, 2.0): 1.0}
# set NG [4. 0.] {(4.0, 0.0): 1.0, (4.0, 2.0): 0.7}
# set NG [4. 2.] {(4.0, 0.0): 0.7, (4.0, 2.0): 1.49}
# set NG [4. 0.] {(4.0, 0.0): 1.49, (4.0, 2.0): 1.043}
# set NG [4. 2.] {(4.0, 0.0): 1.043, (4.0, 2.0): 1.7300999999999997}
# set NG [4. 0.] {(4.0, 0.0): 1.7300999999999997, (4.0, 2.0): 1.2110699999999996}
# set NG [4. 2.] {(4.0, 0.0): 1.2110699999999996, (4.0, 2.0): 1.8477489999999999}
# set NG [4. 0.] {(4.0, 0.0): 1.8477489999999999, (4.0, 2.0): 1.2934242999999999}
# 29
# init 1 2
# init 2 3
# init 3 2
# init 2 4
# init 4 1
# actremapping [187 273] [187 158]
# init 4 1
# set NG [4. 1.] {(4.0, 1.0): 1.0}
# set NG [4. 0.] {(4.0, 0.0): 1.0, (4.0, 1.0): 0.7}
# set NG [4. 1.] {(4.0, 0.0): 0.7, (4.0, 1.0): 1.49}
# set NG [4. 0.] {(4.0, 0.0): 1.49, (4.0, 1.0): 1.043}
# set NG [4. 1.] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.7300999999999997}
# actremapping [167 246 187 273  92  81 165  93] [167 246 187 273  92  81 165  69]
# init 3 2
# init 2 3
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.7300999999999997, (4.0, 1.0): 1.2110699999999996}
# set NG [4. 1.] {(4.0, 0.0): 1.2110699999999996, (4.0, 1.0): 1.8477489999999999}
# set NG [4. 0.] {(4.0, 0.0): 1.8477489999999999, (4.0, 1.0): 1.2934242999999999}
# set NG [4. 1.] {(4.0, 0.0): 1.2934242999999999, (4.0, 1.0): 1.9053970099999997}
# set NG [4. 0.] {(4.0, 0.0): 1.9053970099999997, (4.0, 1.0): 1.3337779069999998}
# set NG [4. 1.] {(4.0, 0.0): 1.3337779069999998, (4.0, 1.0): 1.9336445348999998}
# 30
# init 1 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.0}
# actremapping
2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.0}
# actremapping [282 202 237 240] [282 202 237 144]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 1.] {(4.0, 0.0): 0.7, (4.0, 1.0): 1.0}
# set NG [4. 0.] {(4.0, 0.0): 1.49, (4.0, 1.0): 0.7}
# set NG [4. 1.] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.49}
# actremapping [282 202 237 144 266  71 209 224] [282 202 237 144 266  71 209 212]
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.7300999999999997, (4.0, 1.0): 1.043}
# set NG [4. 1.] {(4.0, 0.0): 1.2110699999999996, (4.0, 1.0): 1.7300999999999997}
# set NG [4. 0.] {(4.0, 0.0): 1.8477489999999999, (4.0, 1.0): 1.2110699999999996}
# set NG [4. 1.] {(4.0, 0.0): 1.2934242999999999, (4.0, 1.0): 1.8477489999999999}
# set NG [4. 0.] {(4.0, 0.0): 1.9053970099999997, (4.0, 1.0): 1.2934242999999999}
# set NG [4. 1.] {(4.0, 0.0): 1.3337779069999998, (4.0, 1.0): 1.9053970099999997}
# set NG [4. 0.] {(4.0, 0.0): 1.9336445348999998, (4.0, 1.0): 1.3337779069999998}
# set NG [4. 1.] {(4.0, 0.0): 1.3535511744299997, (4.0, 1.0): 1.9336445348999998}
# set NG [4. 0.] {(4.0, 0.0): 1.9474858221009996, (4.0, 1.0): 1.3535511744299997}
# set NG [4. 1.] {(4.0, 0.0): 1.3632400754706997, (4.0, 1.0): 1.9474858221009996}
# 39
# init 1 2
# init 2 3
# init 3 2
# init 2 4
# init 4 1
# actremapping [274 139] [274 240]
# init 4 1
# set NG [4. 1.] {(4.0, 1.0): 1.0}
# set NG [4. 0.] {(4.0, 0.0): 1.0, (4.0, 1.0): 0.7}
# set NG [4. 1.] {(4.0, 0.0): 0.7, (4.0, 1.0): 1.49}
# set NG [4. 0.] {(4.0, 0.0): 1.49, (4.0, 1.0): 1.043}
# set NG [4. 1.] {(4.0, 0.0): 1.043, (4.0, 1.0): 1.7300999999999997}
# init 2 3
# init 3 2
# init 2 3
# init 3 2
# init 2 3
# init 3 2
# init 2 4
# init 4 1
# actremapping [ 59 189] [ 59 219]
# init 4 1
# actremapping [ 12 102 274 139 251  97 141  90] [ 12 102 274 139 251  97 141 117]
# init 3 2
# init 2 3
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.7300999999999997, (4.0, 1.0): 1.2110699999999996}
# set NG [4. 1.] {(4.0, 0.0): 1.2110699999999996, (4.0, 1.0): 1.8477489999999999}
# forget 2-2 [59] []
# forget 2-1 [141] [97]
# forget 2-7 [130] []
# forget 2-5 [33] []
# forget 2-3 [292] []
# forget 2-6 [108] []
# forget 2-4 [72] []
# init 2 3
# init 3 2
# init 2 3
# init 3 2
# init 2 4
# init 4 1
# actremapping [110 246] [110 255]
# init 4 1
# set NG [4. 6.] {(4.0, 0.0): 0.8477489999999998, (4.0, 1.0): 1.2934242999999999, (4.0, 6.0): 1.0}
# set NG [4. 6.] {(4.0, 0.0): 0.5934242999999998, (4.0, 1.0): 0.9053970099999998, (4.0, 6.0): 1.0}
# set NG [4. 1.] {(4.0, 0.0): 0.41539700999999984, (4.0, 1.0): 1.0, (4.0, 6.0): 0.7}
# set NG [4. 6.] {(4.0, 0.0): 0.2907779069999999, (4.0, 1.0): 0.7, (4.0, 6.0): 1.49}
# set NG [4. 1.] {(4.0, 0.0): 0.2035445348999999, (4.0, 1.0): 1.49, (4.0, 6.0): 1.043}
# set NG [4. 6.] {(4.0, 0.0): 0.1424811744299999, (4.0, 1.0): 1.043, (4.0, 6.0): 1.7300999999999997}
# set NG [4. 1.] {(4.0, 0.0): 0.09973682210099993, (4.0, 1.0): 1.7300999999999997, (4.0, 6.0): 1.2110699999999996}
# forget 3-5 [200] []
# forget 3-6 [67] []
# forget 3-2 [279] []
# forget 3-4 [152] []
# forget 3-1 [26] []
# forget 3-7 [225] []
# forget 3-3 [215] []
# init 3 2
# init 2 3
# init 3 2
# init 2 3
# init 3 2
# init 2 3
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 6.] {(4.0, 0.0): 0.06981577547069995, (4.0, 1.0): 1.2110699999999996, (4.0, 6.0): 1.0}
# forget 2-11 [44] []
# forget 2-8 [110] [22]
# forget 2-12 [205] []
# forget 2-9 [296] []
# forget 2-10 [285] []
# forget 2-14 [41] []
# forget 2-13 [91] []
# init 2 3
# init 3 2
# init 2 3
# init 3 2
# init 2 4
# forget 4-7 [225] [160]
# forget 4-5 [182] [13]
# forget 4-6 [70] [255]
# forget 4-3 [219] []
# forget 4-1 [217] [240]
# forget 4-2 [234] [173]
# forget 4-4 [69] [112]
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.04887104282949, (4.0, 1.0): 0.8477489999999998, (4.0, 6.0): 0.7}
# actremapping [114 237] [114  65]
# init 4 1
# init 1 2
# init 2 3
# init 3 2
# init 2 3
# forget 3-9 [252] []
# forget 3-12 [118] []
# forget 3-10 [267] []
# forget 3-13 [229] []
# forget 3-8 [73] []
# forget 3-11 [271] []
# forget 3-14 [128] []
# init 3 2
# init 2 4
# init 4 1
# init 2 3
# init 3 2
# forget 2-15 [114] [97]
# forget 2-16 [153] []
# forget 2-17 [208] []
# forget 2-21 [43] []
# forget 2-18 [155] []
# forget 2-20 [37] []
# forget 2-19 [278] []
# init 2 4
# init 4 1
# set NG [ 4. 11.] {(4.0, 0.0): 0.734209729980643, (4.0, 1.0): 0.5934242999999998, (4.0, 6.0): 0.48999999999999994, (4.0, 11.0): 1.0}
# set NG [4. 0.] {(4.0, 0.0): 1.5139468109864502, (4.0, 1.0): 0.41539700999999984, (4.0, 6.0): 0.3429999999999999, (4.0, 11.0): 0.7}
# set NG [ 4. 11.] {(4.0, 0.0): 1.059762767690515, (4.0, 1.0): 0.2907779069999999, (4.0, 6.0): 0.24009999999999992, (4.0, 11.0): 1.49}
# actremapping [274 139 251  97  63 155] [274 139 251  97  63 104]
# init 3 2
# init 2 3
# init 3 2
# init 2 4
# init 4 1
# set NG [4. 0.] {(4.0, 0.0): 1.7418339373833605, (4.0, 1.0): 0.2035445348999999, (4.0, 6.0): 0.16806999999999994, (4.0, 11.0): 1.043}
# 0

# %%
test
# Out:
# [array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([600]),
#  array([357, 359, 360, 361, 364, 600])]

# %%
with open("./pkls/dropby_2times.pkl", mode = "wb") as f:
    pickle.dump(allresult, f)

# %%
with open("./pkls/dropby_2times.pkl", mode = "rb") as f:
    allresult = pickle.load(f)
num = len(allresult)
trialnum = np.max([len(allresult[x]) for x in range(num)])

# %%
rwdrate = np.zeros((num,trialnum))
for x in range(num):
    tmp = [res[-1]["rwd"] for r, res in enumerate(allresult[x])]
    rwdrate[x,:len(tmp)] = tmp

# %%
plt.imshow(rwdrate)

# %%
plt.figure(figsize = (10,4))
for i in range(1,int(trialnum/hp.swblock)-1):
    plt.plot([hp.swblock*i-0.5,hp.swblock*i-0.5], [-5,105], "--",color = "#555555")
plt.errorbar(np.arange(trialnum), np.nanmean(rwdrate,0)*100, 100*np.nanstd(rwdrate,0)/np.sqrt(num),fmt="go-")
plt.xlabel("trial index", fontsize = 20)
plt.ylabel("correct [%]", fontsize = 20)
plt.xticks(np.arange(-0.5,trialnum+1,20),np.arange(0,trialnum+1,20), fontsize = 15)
plt.yticks(fontsize = 15) 
plt.ylim([-5,105])
plt.savefig("./figure/dropby_2times_correct.png", bbox_inches = "tight")

# %%
inflen = np.zeros((num,trialnum))*np.nan
for x in range(num):
    tmp = [int((len(allresult[x][r][-1]["HCtrans"])-1)/2) for r in range(len(allresult[x]))]
    inflen[x,:len(tmp)] = tmp

# %%
plt.figure(figsize = (10,4))
for i in range(1,int(trialnum/hp.swblock)-1):
    plt.plot([hp.swblock*i-0.5,hp.swblock*i-0.5], [0,8], "--",color = "#555555")
for i in range(num):
    plt.plot(np.arange(trialnum), inflen[i,:]+np.random.rand(trialnum)*0, "ko-", linewidth = 0.3, markerfacecolor = (0,0,0,0.05))    
plt.plot(np.arange(trialnum), np.nanmean(inflen,0), "r")
plt.xlabel("trial index", fontsize = 20)
plt.ylabel("planning length", fontsize = 20)
plt.xticks(np.arange(-0.5,trialnum+1,20), np.arange(0,trialnum + 1,20), fontsize = 15)
plt.yticks(np.arange(1,8,2),fontsize = 15)
plt.ylim([.5,8])
plt.savefig("./figure/dropby_2times_inflen.png", bbox_inches = "tight")

# %%
for x in range(2):
    allHCs, allinfs = [], []
    if len(allresult[x]) != trialnum:
        continue
    for y in range(trialnum):
        HCs = []
        for z in range(len(allresult[x][y])):
            tmp = copy.deepcopy(allresult[x][y][z]["HCtrans"])
            if len(tmp) % 2 == 1:
                tmp = tmp[1:]
            arg = np.isin(tmp, HCs)
            HCs.extend(list(tmp[~arg]))
            tmp = allresult[x][y][z]["infcond"]
            if z == 0:
                infs = copy.deepcopy(tmp)
            elif infs[-1] == tmp[0]:
                infs.extend(tmp[1:])
            elif infs[-1] == tmp[-1]:
                continue
            else:
                print(x,y,z,tmp, infs, len(HCs))
        if HCs[0] == HCs[-1]:
            HCs = HCs[:-1]
        if infs[0] == infs[-1]:
            infs = infs[:-1]
        HCs = HCs[:len(infs)*2]
        allHCs.append(HCs)
        allinfs.append(infs)

# %%
mat = np.zeros((2*7, 7))
for i in range(7):
    mat[2*i:2*i+2,i] = 1

# %%
plt.figure(figsize = (4,8))
plt.imshow(mat, cmap = "jet")
plt.plot(np.ones(2)*0.5,[-0.5,13.5], color = "#D648D6")
plt.plot(np.ones(2)*3,[-0.5,13.5], color = "#D648D6")
plt.plot(np.ones(2)*5.5,[-0.5,13.5], color = "#D648D6")
plt.tick_params(left = False, right = False , labelleft = False ,
                labelbottom = False, bottom = False)
plt.savefig("./figure/dropby_2times_firing.png", bbox_inches = "tight")
